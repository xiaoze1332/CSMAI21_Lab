# %%
import pandas as pd

# %%
wine = pd.read_csv("/content/CS3AI18_CSMAI21_lab2_wine.csv")

# %%
wine.head()
# Out:
#    Unnamed: 0  fixed.acidity  volatile.acidity  ...  quality   type  quality_ind
# 0           1            7.0              0.27  ...        6  White          Low
# 1           2            6.3              0.30  ...        6  White          Low
# 2           3            8.1              0.28  ...        6  White          Low
# 3           4            7.2              0.23  ...        6  White          Low
# 4           5            7.2              0.23  ...        6  White          Low
#
# [5 rows x 15 columns]

# %%
X = wine.iloc[:,2:11]
y = wine.iloc[:,14]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(criterion='entropy',random_state=0)

# %%
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree, out_file='tree.dot')

# %%
tree.predict(X.iloc[:1,:])
# Out:
# array(['Low'], dtype=object)

# %%
tree.predict_proba(X.iloc[:1,:])
# Out:
# array([[0., 1.]])
