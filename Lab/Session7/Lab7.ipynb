# %% [markdown]
# # Task 2

# %%
import time

# %%
# first neural network with keras tutorial
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense

# %%
...
# load the dataset
dataset = loadtxt('https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv', delimiter=',')
# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]

# %%
# define the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
start = time.perf_counter()
model.fit(X, y, epochs=150, batch_size=10)
end = time.perf_counter()
print("time consuming : %.2fs"%(end - start))

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5185 - accuracy: 0.7565
# Accuracy: 75.65

# %% [markdown]
# # Task 3

# %%
#Import libraries
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, AveragePooling2D

# %%
#Load MNIST dataset and split it into training and test sets
mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()

# %%
#Reshape image dimensions
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

# %%
#Normalize data
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
#Build the model
model = Sequential()
model.add(Conv2D(filters=6, kernel_size=(3, 3), activation='tanh', input_shape=(28,28,1)))
model.add(AveragePooling2D())
model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='tanh'))
model.add(AveragePooling2D())
model.add(Flatten())
model.add(Dense(units=128, activation='tanh'))
model.add(Dense(units=10, activation = 'softmax')) #10 digit classes as outputs
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 6)         60
#
#  average_pooling2d (AverageP  (None, 13, 13, 6)        0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 16)        880
#
#  average_pooling2d_1 (Averag  (None, 5, 5, 16)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 400)               0
#
#  dense (Dense)               (None, 128)               51328
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 53,558
# Trainable params: 53,558
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#Fit the model
model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 21s 5ms/step - loss: 0.2917 - accuracy: 0.9128 - val_loss: 0.1544 - val_accuracy: 0.9539
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1251 - accuracy: 0.9621 - val_loss: 0.1034 - val_accuracy: 0.9669
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0854 - accuracy: 0.9742 - val_loss: 0.0729 - val_accuracy: 0.9775
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0648 - accuracy: 0.9806 - val_loss: 0.0677 - val_accuracy: 0.9774
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0517 - accuracy: 0.9841 - val_loss: 0.0573 - val_accuracy: 0.9814
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0421 - accuracy: 0.9865 - val_loss: 0.0539 - val_accuracy: 0.9828
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0346 - accuracy: 0.9893 - val_loss: 0.0509 - val_accuracy: 0.9834
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0293 - accuracy: 0.9911 - val_loss: 0.0455 - val_accuracy: 0.9850
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0244 - accuracy: 0.9930 - val_loss: 0.0476 - val_accuracy: 0.9851
# Epoch 10/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0214 - accuracy: 0.9935 - val_loss: 0.0497 - val_accuracy: 0.9835

# %%
#Evaluate the model
score = model.evaluate(X_test, y_test)
print("Test score:", score[0])
print('Test accuracy:', score[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8e272bc26fcf> in <module>()
#       1 #Evaluate the model
# ----> 2 score = model.evaluate(X_test, y_test)
#       3 print("Test score:", score[0])
#       4 print('Test accuracy:', score[1])
#
# NameError: name 'X_test' is not defined
